# %%
import pandas as pd
import os
import glob

# %% [markdown]
# ### 1     Merging CSVs
#
# https://www.techbeamers.com/pandas-merge-csv-files/

# %%
#pd.read_csv('./Sales_Data/Sales_April_2019.csv')

# %%
path = './Sales_Data/'

# %%
list_of_files = [file for file in os.listdir(path)]
print(list_of_files)
# Out:
# ['Sales_December_2019.csv', 'Sales_April_2019.csv', 'Sales_February_2019.csv', 'Sales_March_2019.csv', 'Sales_August_2019.csv', 'Sales_May_2019.csv', 'Sales_November_2019.csv', 'Sales_October_2019.csv', 'Sales_January_2019.csv', 'Sales_September_2019.csv', 'Sales_July_2019.csv', 'Sales_June_2019.csv']

# %%
filenames = glob.glob(path + "/*.csv")

# %%
print(filenames)
# Out:
# ['./Sales_Data/Sales_December_2019.csv', './Sales_Data/Sales_April_2019.csv', './Sales_Data/Sales_February_2019.csv', './Sales_Data/Sales_March_2019.csv', './Sales_Data/Sales_August_2019.csv', './Sales_Data/Sales_May_2019.csv', './Sales_Data/Sales_November_2019.csv', './Sales_Data/Sales_October_2019.csv', './Sales_Data/Sales_January_2019.csv', './Sales_Data/Sales_September_2019.csv', './Sales_Data/Sales_July_2019.csv', './Sales_Data/Sales_June_2019.csv']

# %%
li = []

for filename in filenames:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)

# %%
df.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %%
df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
print(df['Order Date'][0])
print(df['Order Date'][0][:2])
int(df['Order Date'][0][:2])
# Out:
# 12/30/19 00:01
# 12
# 12

# %% [markdown]
# # What was best month for sales?

# %%
type(df['Order Date'].str[:2])
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
df['Month'] = df['Order Date'].str[:2]

# %%
df.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address Month
# 0  136 Church St, New York City, NY 10001    12
# 1     562 2nd St, New York City, NY 10001    12
# 2    277 Main St, New York City, NY 10001    12
# 3     410 6th St, San Francisco, CA 94016    12
# 4           43 Hill St, Atlanta, GA 30301    12

# %%
df['Month'] = pd.to_numeric(df['Month'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Or"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-51e0a43e7639> in <module>()
# ----> 1 df['Month'] = pd.to_numeric(df['Month'])
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     131             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     132             values = lib.maybe_convert_numeric(values, set(),
# --> 133                                                coerce_numeric=coerce_numeric)
#     134
#     135     except Exception:
#
# ...

# %%
df[df['Month']=='Or'].head()
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 254   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 705   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1101  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2875  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3708  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#       Purchase Address Month
# 254   Purchase Address    Or
# 705   Purchase Address    Or
# 1101  Purchase Address    Or
# 2875  Purchase Address    Or
# 3708  Purchase Address    Or

# %%
df = df.dropna()

# %%
df[df['Month']=='Or'].head()
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 254   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 705   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1101  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2875  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3708  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#       Purchase Address Month
# 254   Purchase Address    Or
# 705   Purchase Address    Or
# 1101  Purchase Address    Or
# 2875  Purchase Address    Or
# 3708  Purchase Address    Or

# %%
df = df[df['Month'] != 'Or']

# %%
df['Month'] = pd.to_numeric(df['Month'])

# %%
df.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# Month                int64
# dtype: object

# %%
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'])
df['Price Each'] = pd.to_numeric(df['Price Each'])

# %%
df.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered      int64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# Month                 int64
# dtype: object

# %%
df['Total Sale'] = df['Quantity Ordered'] * df['Price Each']

# %%
df = df.drop(columns='Quantityt Ordered')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-95401a8b3f5c> in <module>()
# ----> 1 df = df.drop(columns='Quantityt Ordered')
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address  Month  Total Sale
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001     12     1700.00
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001     12      600.00
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001     12       11.95
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016     12      149.99
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12       11.95

# %%
month_df = df.groupby('Month')

# %%
month_df.sum()
# Out:
#        Quantity Ordered    Price Each    Total Sale
# Month
# 1                 10903  1.811768e+06  1.822257e+06
# 2                 13449  2.188885e+06  2.202022e+06
# 3                 17005  2.791208e+06  2.807100e+06
# 4                 20558  3.367671e+06  3.390670e+06
# 5                 18667  3.135125e+06  3.152607e+06
# 6                 15253  2.562026e+06  2.577802e+06
# 7                 16072  2.632540e+06  2.647776e+06
# 8                 13448  2.230345e+06  2.244468e+06
# 9                 13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %%
df['Purchase Address'].head()
# Out:
# 0    136 Church St, New York City, NY 10001
# 1       562 2nd St, New York City, NY 10001
# 2      277 Main St, New York City, NY 10001
# 3       410 6th St, San Francisco, CA 94016
# 4             43 Hill St, Atlanta, GA 30301
# Name: Purchase Address, dtype: object

# %%
df['City'] = df['Purchase Address'].str.split(pat=',', expand=True)[1]

# %%
df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address  Month  Total Sale  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001     12     1700.00
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001     12      600.00
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001     12       11.95
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016     12      149.99
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12       11.95
#
#              City
# 0   New York City
# 1   New York City
# 2   New York City
# 3   San Francisco
# 4         Atlanta

# %%
df.groupby('City').sum()
# Out:
#                 Quantity Ordered    Price Each   Month    Total Sale
# City
#  Atlanta                   16602  2.779908e+06  104794  2.795499e+06
#  Austin                    11153  1.809874e+06   69829  1.819582e+06
#  Boston                    22528  3.637410e+06  141112  3.661642e+06
#  Dallas                    16730  2.752628e+06  104620  2.767975e+06
#  Los Angeles               33289  5.421435e+06  208325  5.452571e+06
#  New York City             27932  4.635371e+06  175741  4.664317e+06
#  Portland                  14053  2.307747e+06   87765  2.320491e+06
#  San Francisco             50239  8.211462e+06  315520  8.262204e+06
#  Seattle                   16553  2.733296e+06  104941  2.747755e+06

# %%
df['City'] + ' ' + df['Purchase Address']
# Out:
# 0          New York City 136 Church St, New York City, N...
# 1          New York City 562 2nd St, New York City, NY 1...
# 2          New York City 277 Main St, New York City, NY ...
# 3          San Francisco 410 6th St, San Francisco, CA 9...
# 4                     Atlanta 43 Hill St, Atlanta, GA 30301
# 5          New York City 200 Jefferson St, New York City...
# 6                  Portland 928 12th St, Portland, OR 97035
# 7                   Dallas 813 Hickory St, Dallas, TX 75001
# 8                    Dallas 718 Wilson St, Dallas, TX 75001
# 9                        Dallas 77 7th St, Dallas, TX 75001
# 10         San Francisco 594 1st St, San Francisco, CA 9...
# 11         Los Angeles 410 Lincoln St, Los Angeles, CA 9...
# 12                     Boston 866 Pine St, Boston, MA 02215
# 13                  Dallas 187 Lincoln St, Dallas, TX 75001
# 14                      Dallas 902 2nd St, Dallas, TX 75001
# 15                     Austin 338 Main St, Austin, TX 73301
# ...

# %%
df['Purchase Address'].str.split(pat=',', expand=True)[2].head()
# Out:
# 0     NY 10001
# 1     NY 10001
# 2     NY 10001
# 3     CA 94016
# 4     GA 30301
# Name: 2, dtype: object

# %%
df['State'] = df['Purchase Address'].str.split(pat=',', expand=True)[2]
df['State'] = df['State'].str.split(pat=' ', expand=True)[1]

# %%
df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address  Month  Total Sale  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001     12     1700.00
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001     12      600.00
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001     12       11.95
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016     12      149.99
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12       11.95
#
#              City State
# 0   New York City    NY
# 1   New York City    NY
# 2   New York City    NY
# ...

# %%
df['City'] = df['City'] + ', ' + df['State']

# %%
df.groupby('City').sum()
# Out:
#                        Quantity Ordered    Price Each   Month    Total Sale
# City
#  Atlanta GA, GA                   16602  2.779908e+06  104794  2.795499e+06
#  Austin TX, TX                    11153  1.809874e+06   69829  1.819582e+06
#  Boston MA, MA                    22528  3.637410e+06  141112  3.661642e+06
#  Dallas TX, TX                    16730  2.752628e+06  104620  2.767975e+06
#  Los Angeles CA, CA               33289  5.421435e+06  208325  5.452571e+06
#  New York City NY, NY             27932  4.635371e+06  175741  4.664317e+06
#  Portland ME, ME                   2750  4.471893e+05   17144  4.497583e+05
#  Portland OR, OR                  11303  1.860558e+06   70621  1.870732e+06
#  San Francisco CA, CA             50239  8.211462e+06  315520  8.262204e+06
#  Seattle WA, WA                   16553  2.733296e+06  104941  2.747755e+06

# %%
df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address  Month  Total Sale  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001     12     1700.00
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001     12      600.00
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001     12       11.95
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016     12      149.99
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12       11.95
#
#                     City State
# 0   New York City NY, NY    NY
# 1   New York City NY, NY    NY
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df['Hour'] = df['Order Date'].dt.hour

# %%
hours_df = df.groupby('Hour').sum()

hours_df
# Out:
#       Quantity Ordered  Price Each  Month  Total Sale
# Hour
# 0                 4428   709296.70  27554   713721.27
# 1                 2619   458490.00  16657   460866.88
# 2                 1398   233833.64   8507   234851.44
# 3                  928   144726.42   5904   145757.89
# 4                  937   162058.18   6148   162661.01
# 5                 1493   229621.21   9301   230679.82
# 6                 2810   445000.11  17539   448113.00
# 7                 4556   740568.11  28850   744854.12
# 8                 7002  1185970.62  43626  1192348.97
# 9                 9816  1628498.49  60981  1639030.58
# 10               12308  1932665.62  76928  1944286.77
# 11               14005  2288855.18  87654  2300610.24
# 12               14202  2299876.68  89161  2316821.34
# 13               13685  2139743.86  85808  2155389.80
# 14               12362  2072194.77  77836  2083672.73
# 15               11391  1931174.99  72060  1941549.60
# ...

# %%
hours_df.sort_values(by=['Total Sale'], ascending=False)
# Out:
#       Quantity Ordered  Price Each  Month  Total Sale
# Hour
# 19               14470  2398588.31  91389  2412938.54
# 12               14202  2299876.68  89161  2316821.34
# 11               14005  2288855.18  87654  2300610.24
# 20               13768  2268185.16  86375  2281716.24
# 18               13802  2207696.93  86421  2219348.30
# 13               13685  2139743.86  85808  2155389.80
# 17               12229  2116777.02  77454  2129361.61
# 14               12362  2072194.77  77836  2083672.73
# 21               12244  2030763.83  77103  2042000.86
# 10               12308  1932665.62  76928  1944286.77
# 15               11391  1931174.99  72060  1941549.60
# 16               11662  1892454.54  72939  1904601.31
# 9                 9816  1628498.49  60981  1639030.58
# 22                9899  1599464.44  62088  1607549.21
# 8                 7002  1185970.62  43626  1192348.97
# 23                7065  1172625.87  44364  1179304.44
# ...

# %%
multiple_items_df = df[df['Order ID'].duplicated(keep=False)]

# %%
multiple_items_df.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 16   295681                Google Phone                 1      600.00
# 17   295681        USB-C Charging Cable                 1       11.95
# 18   295681  Bose SoundSport Headphones                 1       99.99
# 19   295681            Wired Headphones                 1       11.99
# 36   295698             Vareebadd Phone                 1      400.00
#
#             Order Date                     Purchase Address  Month  \
# 16 2019-12-25 12:37:00          79 Elm St, Boston, MA 02215     12
# 17 2019-12-25 12:37:00          79 Elm St, Boston, MA 02215     12
# 18 2019-12-25 12:37:00          79 Elm St, Boston, MA 02215     12
# 19 2019-12-25 12:37:00          79 Elm St, Boston, MA 02215     12
# 36 2019-12-13 14:32:00  175 1st St, New York City, NY 10001     12
#
#     Total Sale                   City State  Hour
# 16      600.00          Boston MA, MA    MA    12
# ...

# %%
multiple_items_df['grouped'] = multiple_items_df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
multiple_items_df['grouped']
# Out:
# 16        Google Phone,USB-C Charging Cable,Bose SoundSp...
# 17        Google Phone,USB-C Charging Cable,Bose SoundSp...
# 18        Google Phone,USB-C Charging Cable,Bose SoundSp...
# 19        Google Phone,USB-C Charging Cable,Bose SoundSp...
# 36                     Vareebadd Phone,USB-C Charging Cable
# 37                     Vareebadd Phone,USB-C Charging Cable
# 42         AA Batteries (4-pack),Bose SoundSport Headphones
# 43         AA Batteries (4-pack),Bose SoundSport Headphones
# 66                          iPhone,Lightning Charging Cable
# 67                          iPhone,Lightning Charging Cable
# 76         iPhone,Apple Airpods Headphones,Wired Headphones
# 77         iPhone,Apple Airpods Headphones,Wired Headphones
# 78         iPhone,Apple Airpods Headphones,Wired Headphones
# 80                          iPhone,Lightning Charging Cable
# 81                          iPhone,Lightning Charging Cable
# 97          34in Ultrawide Monitor,Lightning Charging Cable
# ...

# %%
multiple_items_df = multiple_items_df[['Order ID', 'grouped']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-c797e4d43ee7> in <module>()
# ----> 1 multiple_items_df = multiple_items_df[['Order ID', 'grouped']]
#
# TypeError: 'method' object is not subscriptable

# %%
multiple_items_df()
# Out:
#        Order ID                                            grouped
# 16       295681  Google Phone,USB-C Charging Cable,Bose SoundSp...
# 36       295698               Vareebadd Phone,USB-C Charging Cable
# 42       295703   AA Batteries (4-pack),Bose SoundSport Headphones
# 66       295726                    iPhone,Lightning Charging Cable
# 76       295735   iPhone,Apple Airpods Headphones,Wired Headphones
# 80       295737                    iPhone,Lightning Charging Cable
# 97       295753    34in Ultrawide Monitor,Lightning Charging Cable
# 104      295759        Bose SoundSport Headphones,Wired Headphones
# 129      295783               Vareebadd Phone,USB-C Charging Cable
# 133      295786      USB-C Charging Cable,Apple Airpods Headphones
# 141      295793                  Google Phone,USB-C Charging Cable
# 166      295817                  USB-C Charging Cable,20in Monitor
# 172      295822                      Google Phone,Wired Headphones
# ...
